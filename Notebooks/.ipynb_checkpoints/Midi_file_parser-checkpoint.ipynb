# %%
import struct

def read_variable_length(data, offset):
    # reads a variable acording to the midi the bottom 7 bits are used for value
    # if the 8th bit is 0 the value is done if the 8th bit is 1 grabs one more byte
    value = 0
    while True:
        byte = data[offset]
        offset += 1
        value = (value << 7) | (byte & 0x7F)
        if not (byte & 0x80):
            break
    return value, offset
    
def readMidiFile(path):
    src = open(path, "rb")
    current_ticks = 0
    tempo = 500000
    ticks_per_quarter = 480
    header_dict = {}
    while True:
        chunkID = src.read(4)
        chunklen = int.from_bytes(src.read(4))
        chunk = src.read(chunklen)
        delta_times = False
        if chunkID == b'MThd':
            header_dict['format'], header_dict['ntracks'], header_dict['tickdiv']  = struct.unpack('>HHH', chunk[0:6])
            header_dict['µs_per_tick'] = tempo/header_dict['tickdiv'] 
            if header_dict['format'] != 1:
                    print('Only format 1 MIDI files are suported')
            print('Header: ', header_dict)
        elif chunkID == b'MTrk':
            offset = 0
            print("track:")
            #print(chunk)
            while offset < chunklen:
                # Read delta time
                delta, offset = read_variable_length(chunk, offset)
                current_ticks += delta
                event_status = chunk[offset]
                offset += 1
                if event_status == 0xFF: #Meta event
                    meta_type = chunk[offset]
                    offset += 1
                    meta_length = chunk[offset]
                    offset += 1
                    meta_data = chunk[offset:offset+meta_length]
                    offset += meta_length
                    if meta_type == 0x2F and meta_data == b'':
                        print(current_ticks,"- Metadata > End of track")
                    elif meta_type == 0x03:
                        print(current_ticks,"- Metadata > Track/Sequence name > ",meta_data)
                    elif meta_type == 0x51:
                        tempo = struct.unpack('>i', b'\x00'+meta_data)[0]
                        header_dict['µs_per_tick'] = tempo/header_dict['tickdiv']
                        print(current_ticks,"- Metadata > Tempo > ",tempo)
                    elif meta_type == 0x58:
                        num, denom, clocks_per_clck, notes_per_beat = struct.unpack('>bbbb', meta_data)
                        print(current_ticks,"- Metadata > Time signature >",num, denom, clocks_per_clck, notes_per_beat)
                    else:
                        print(current_ticks,'- type - ',meta_type,' - Meta Data > ',meta_data)
                elif event_status//16 == 9 or event_status//16 == 8:
                    note = chunk[offset]
                    offset += 1
                    vel = chunk[offset]
                    offset += 1
                    if event_status//16 == 9:
                        note_ac = 'Note On'
                    else:
                        note_ac = 'Note Off'
                    print(note_ac+' > n:',note,' v:',vel,'t:',int(current_ticks*header_dict['µs_per_tick']))
                elif event_status//16 == 11:
                    controller = chunk[offset]
                    offset += 1
                    value = chunk[offset]
                    offset += 1
                    print(current_ticks,' - controller > ctrl: ',controller,'val: ',value)
                elif event_status//16 == 12:
                    pgrm_n = chunk[offset]
                    offset += 1
                    print(current_ticks,' - program > pgrm_n: ',pgrm_n)
                elif event_status//16 == 14:
                    lsb = chunk[offset]
                    offset += 1
                    msb = chunk[offset]
                    offset += 1
                    print(current_ticks,' - pitchBend > lsb: ',lsb,' msb: ',msb)
                else:
                    print(current_ticks,' - ',hex(event_status))
        else:
            break

# %%
mid = readMidiFile('../ChipTune Melodies/Kid Dracula - Go-Go at the Great Castle.mid')
# Out:
# Header:  {'format': 1, 'ntracks': 2, 'tickdiv': 480, 'µs_per_tick': 1041.6666666666667}
# track:
# 0 - Metadata > Track/Sequence name >  b''
# 0 - Metadata > Time signature > 4 2 24 8
# 0 - Metadata > Tempo >  535714
# 0 - Metadata > End of track
# track:
# 0  - controller > ctrl:  121 val:  0
# 0 - Metadata > Track/Sequence name >  b'main track'
# 0  - controller > ctrl:  10 val:  64
# 0  - controller > ctrl:  7 val:  100
# 0  - controller > ctrl:  11 val:  127
# 0  - controller > ctrl:  101 val:  0
# 0  - controller > ctrl:  100 val:  2
# 0  - controller > ctrl:  6 val:  64
# 0  - controller > ctrl:  101 val:  0
# 0  - controller > ctrl:  100 val:  1
# 0  - controller > ctrl:  6 val:  64
# 0  - controller > ctrl:  38 val:  0
# 0  - controller > ctrl:  101 val:  0
# 0  - controller > ctrl:  100 val:  0
# 0  - controller > ctrl:  6 val:  12
# 0  - pitchBend > lsb:  0  msb:  64
# 0  - controller > ctrl:  1 val:  0
# 0  - program > pgrm_n:  80
# Note On > n: 85  v: 100 t: 803571
# Note Off > n: 85  v: 0 t: 1071428
# Note On > n: 83  v: 100 t: 1071428
# Note Off > n: 83  v: 0 t: 1339285
# Note On > n: 81  v: 100 t: 1339285
# Note Off > n: 81  v: 0 t: 1607142
# Note On > n: 76  v: 100 t: 1607142
# Note Off > n: 76  v: 0 t: 2410713
# Note On > n: 81  v: 100 t: 2678570
# Note Off > n: 81  v: 0 t: 2946427
# Note On > n: 83  v: 100 t: 2946427
# Note Off > n: 83  v: 0 t: 3482141
# Note On > n: 85  v: 100 t: 3482141
# Note Off > n: 85  v: 0 t: 4017855
# Note On > n: 81  v: 100 t: 4017855
# Note Off > n: 81  v: 0 t: 4553569
# Note On > n: 86  v: 100 t: 4553569
# Note Off > n: 86  v: 0 t: 5357140
# Note On > n: 85  v: 100 t: 5357140
# Note Off > n: 85  v: 0 t: 6160711
# Note On > n: 82  v: 100 t: 6160711
# Note Off > n: 82  v: 0 t: 6696425
# Note On > n: 83  v: 100 t: 6696425
# Note Off > n: 83  v: 0 t: 7499996
# Note On > n: 85  v: 100 t: 7767853
# Note Off > n: 85  v: 0 t: 8035710
# Note On > n: 83  v: 100 t: 8035710
# Note Off > n: 83  v: 0 t: 8303567
# Note On > n: 81  v: 100 t: 8303567
# Note Off > n: 81  v: 0 t: 8571424
# Note On > n: 76  v: 100 t: 8571424
# Note Off > n: 76  v: 0 t: 9374995
# Note On > n: 81  v: 100 t: 9374995
# Note Off > n: 81  v: 0 t: 9642852
# Note On > n: 83  v: 100 t: 9642852
# Note Off > n: 83  v: 0 t: 10178566
# Note On > n: 85  v: 100 t: 10178566
# Note Off > n: 85  v: 0 t: 10714280
# Note On > n: 88  v: 100 t: 10714280
# Note Off > n: 88  v: 0 t: 11249994
# Note On > n: 86  v: 100 t: 11249994
# Note Off > n: 86  v: 0 t: 12321422
# Note On > n: 88  v: 100 t: 12321422
# Note Off > n: 88  v: 0 t: 13392850
# Note On > n: 90  v: 100 t: 13392850
# Note Off > n: 90  v: 0 t: 13660707
# Note On > n: 90  v: 100 t: 13928564
# Note Off > n: 90  v: 0 t: 14732135
# Note On > n: 85  v: 100 t: 14999992
# Note Off > n: 85  v: 0 t: 15267849
# Note On > n: 83  v: 100 t: 15267849
# Note Off > n: 83  v: 0 t: 15535706
# Note On > n: 81  v: 100 t: 15535706
# Note Off > n: 81  v: 0 t: 15803563
# Note On > n: 76  v: 100 t: 15803563
# Note Off > n: 76  v: 0 t: 16607134
# Note On > n: 81  v: 100 t: 16607134
# Note Off > n: 81  v: 0 t: 16874991
# Note On > n: 83  v: 100 t: 16874991
# Note Off > n: 83  v: 0 t: 17410705
# Note On > n: 85  v: 100 t: 17410705
# Note Off > n: 85  v: 0 t: 17946419
# Note On > n: 81  v: 100 t: 17946419
# Note Off > n: 81  v: 0 t: 18482133
# Note On > n: 86  v: 100 t: 18482133
# Note Off > n: 86  v: 0 t: 19285704
# Note On > n: 85  v: 100 t: 19285704
# Note Off > n: 85  v: 0 t: 20089275
# Note On > n: 82  v: 100 t: 20089275
# Note Off > n: 82  v: 0 t: 20624989
# Note On > n: 83  v: 100 t: 20624989
# Note Off > n: 83  v: 0 t: 21428560
# Note On > n: 85  v: 100 t: 21428560
# Note Off > n: 85  v: 0 t: 21696417
# Note On > n: 85  v: 100 t: 21696417
# Note Off > n: 85  v: 0 t: 21964274
# Note On > n: 83  v: 100 t: 21964274
# Note Off > n: 83  v: 0 t: 22232131
# Note On > n: 81  v: 100 t: 22232131
# Note Off > n: 81  v: 0 t: 22499988
# Note On > n: 76  v: 100 t: 22499988
# Note Off > n: 76  v: 0 t: 23303559
# Note On > n: 81  v: 100 t: 23571416
# Note Off > n: 81  v: 0 t: 23839273
# Note On > n: 83  v: 100 t: 23839273
# Note Off > n: 83  v: 0 t: 24374987
# Note On > n: 85  v: 100 t: 24374987
# Note Off > n: 85  v: 0 t: 24910701
# Note On > n: 88  v: 100 t: 24910701
# Note Off > n: 88  v: 0 t: 25446415
# Note On > n: 86  v: 100 t: 25446415
# Note Off > n: 86  v: 0 t: 26249986
# Note On > n: 87  v: 100 t: 26249986
# Note Off > n: 87  v: 0 t: 27053557
# Note On > n: 88  v: 100 t: 27053557
# Note Off > n: 88  v: 0 t: 27589271
# Note On > n: 90  v: 100 t: 27589271
# Note Off > n: 90  v: 0 t: 27857128
# Note On > n: 92  v: 100 t: 27857128
# Note Off > n: 92  v: 0 t: 28660699
# Note On > n: 93  v: 100 t: 28928556
# Note Off > n: 93  v: 0 t: 29464270
# Note On > n: 93  v: 100 t: 29464270
# Note Off > n: 93  v: 0 t: 29732127
# Note On > n: 90  v: 100 t: 29732127
# Note Off > n: 90  v: 0 t: 29999984
# Note On > n: 93  v: 100 t: 29999984
# Note Off > n: 93  v: 0 t: 30267841
# Note On > n: 90  v: 100 t: 30267841
# Note Off > n: 90  v: 0 t: 30535698
# Note On > n: 86  v: 100 t: 30535698
# Note Off > n: 86  v: 0 t: 31071412
# Note On > n: 84  v: 100 t: 31071412
# Note Off > n: 84  v: 0 t: 31339269
# Note On > n: 90  v: 100 t: 31607126
# Note Off > n: 90  v: 0 t: 31874983
# Note On > n: 83  v: 100 t: 31874983
# Note Off > n: 83  v: 0 t: 32142840
# Note On > n: 90  v: 100 t: 32142840
# Note Off > n: 90  v: 0 t: 32410697
# Note On > n: 93  v: 100 t: 32410697
# Note Off > n: 93  v: 0 t: 32946411
# Note On > n: 95  v: 100 t: 32946411
# Note Off > n: 95  v: 0 t: 33482125
# Note On > n: 93  v: 100 t: 33482125
# Note Off > n: 93  v: 0 t: 34285696
# Note On > n: 88  v: 100 t: 34285696
# Note Off > n: 88  v: 0 t: 35089267
# Note On > n: 88  v: 100 t: 35089267
# Note Off > n: 88  v: 0 t: 35357124
# Note On > n: 83  v: 100 t: 35357124
# Note Off > n: 83  v: 0 t: 35624981
# Note On > n: 84  v: 100 t: 35624981
# Note Off > n: 84  v: 0 t: 36160695
# Note On > n: 85  v: 100 t: 36160695
# Note Off > n: 85  v: 0 t: 36696409
# Note On > n: 93  v: 100 t: 37232123
# Note Off > n: 93  v: 0 t: 37767837
# Note On > n: 93  v: 100 t: 37767837
# Note Off > n: 93  v: 0 t: 38035694
# Note On > n: 90  v: 100 t: 38035694
# Note Off > n: 90  v: 0 t: 38303551
# Note On > n: 93  v: 100 t: 38303551
# Note Off > n: 93  v: 0 t: 38571408
# Note On > n: 90  v: 100 t: 38571408
# Note Off > n: 90  v: 0 t: 38839265
# Note On > n: 86  v: 100 t: 38839265
# Note Off > n: 86  v: 0 t: 39107122
# Note On > n: 84  v: 100 t: 39107122
# Note Off > n: 84  v: 0 t: 39642836
# Note On > n: 90  v: 100 t: 39642836
# Note Off > n: 90  v: 0 t: 39910693
# Note On > n: 83  v: 100 t: 39910693
# Note Off > n: 83  v: 0 t: 40178550
# Note On > n: 90  v: 100 t: 40178550
# Note Off > n: 90  v: 0 t: 40446407
# Note On > n: 83  v: 100 t: 40446407
# Note Off > n: 83  v: 0 t: 40982121
# Note On > n: 81  v: 100 t: 40982121
# Note Off > n: 81  v: 0 t: 41517835
# Note On > n: 80  v: 100 t: 41517835
# Note Off > n: 80  v: 0 t: 42053549
# Note On > n: 88  v: 100 t: 42053549
# Note Off > n: 88  v: 0 t: 42589263
# Note On > n: 81  v: 100 t: 42589263
# Note Off > n: 81  v: 0 t: 43124977
# Note On > n: 90  v: 100 t: 43124977
# Note Off > n: 90  v: 0 t: 43392834
# Note On > n: 83  v: 100 t: 43392834
# Note Off > n: 83  v: 0 t: 43928548
# Note On > n: 76  v: 100 t: 43928548
# Note Off > n: 76  v: 0 t: 44732119
# 40080 - Metadata > End of track

# %%
from mido import MidiFile

# Load the MIDI file
mid = MidiFile('../ChipTune Melodies/Kid Dracula - Go-Go at the Great Castle.mid')

# Print file metadata
print(f"Type: {mid.type}, Ticks per beat: {mid.ticks_per_beat}")

# Iterate through tracks and messages
for track in mid.tracks:
    for msg in track:
        print(msg)
# Out:
# Type: 1, Ticks per beat: 480
# MetaMessage('track_name', name='', time=0)
# MetaMessage('time_signature', numerator=4, denominator=4, clocks_per_click=24, notated_32nd_notes_per_beat=8, time=0)
# MetaMessage('set_tempo', tempo=535714, time=0)
# MetaMessage('end_of_track', time=0)
# control_change channel=0 control=121 value=0 time=0
# MetaMessage('track_name', name='main track', time=0)
# control_change channel=0 control=10 value=64 time=0
# control_change channel=0 control=7 value=100 time=0
# control_change channel=0 control=11 value=127 time=0
# control_change channel=0 control=101 value=0 time=0
# control_change channel=0 control=100 value=2 time=0
# control_change channel=0 control=6 value=64 time=0
# control_change channel=0 control=101 value=0 time=0
# control_change channel=0 control=100 value=1 time=0
# control_change channel=0 control=6 value=64 time=0
# control_change channel=0 control=38 value=0 time=0
# control_change channel=0 control=101 value=0 time=0
# control_change channel=0 control=100 value=0 time=0
# control_change channel=0 control=6 value=12 time=0
# pitchwheel channel=0 pitch=0 time=0
# control_change channel=0 control=1 value=0 time=0
# program_change channel=0 program=80 time=0
# note_on channel=0 note=85 velocity=100 time=720
# note_off channel=0 note=85 velocity=0 time=240
# note_on channel=0 note=83 velocity=100 time=0
# note_off channel=0 note=83 velocity=0 time=240
# note_on channel=0 note=81 velocity=100 time=0
# note_off channel=0 note=81 velocity=0 time=240
# note_on channel=0 note=76 velocity=100 time=0
# note_off channel=0 note=76 velocity=0 time=720
# note_on channel=0 note=81 velocity=100 time=240
# note_off channel=0 note=81 velocity=0 time=240
# note_on channel=0 note=83 velocity=100 time=0
# note_off channel=0 note=83 velocity=0 time=480
# note_on channel=0 note=85 velocity=100 time=0
# note_off channel=0 note=85 velocity=0 time=480
# note_on channel=0 note=81 velocity=100 time=0
# note_off channel=0 note=81 velocity=0 time=480
# note_on channel=0 note=86 velocity=100 time=0
# note_off channel=0 note=86 velocity=0 time=720
# note_on channel=0 note=85 velocity=100 time=0
# note_off channel=0 note=85 velocity=0 time=720
# note_on channel=0 note=82 velocity=100 time=0
# note_off channel=0 note=82 velocity=0 time=480
# note_on channel=0 note=83 velocity=100 time=0
# note_off channel=0 note=83 velocity=0 time=720
# note_on channel=0 note=85 velocity=100 time=240
# note_off channel=0 note=85 velocity=0 time=240
# note_on channel=0 note=83 velocity=100 time=0
# note_off channel=0 note=83 velocity=0 time=240
# note_on channel=0 note=81 velocity=100 time=0
# note_off channel=0 note=81 velocity=0 time=240
# note_on channel=0 note=76 velocity=100 time=0
# note_off channel=0 note=76 velocity=0 time=720
# note_on channel=0 note=81 velocity=100 time=0
# note_off channel=0 note=81 velocity=0 time=240
# note_on channel=0 note=83 velocity=100 time=0
# note_off channel=0 note=83 velocity=0 time=480
# note_on channel=0 note=85 velocity=100 time=0
# note_off channel=0 note=85 velocity=0 time=480
# note_on channel=0 note=88 velocity=100 time=0
# note_off channel=0 note=88 velocity=0 time=480
# note_on channel=0 note=86 velocity=100 time=0
# note_off channel=0 note=86 velocity=0 time=960
# note_on channel=0 note=88 velocity=100 time=0
# note_off channel=0 note=88 velocity=0 time=960
# note_on channel=0 note=90 velocity=100 time=0
# note_off channel=0 note=90 velocity=0 time=240
# note_on channel=0 note=90 velocity=100 time=240
# note_off channel=0 note=90 velocity=0 time=720
# note_on channel=0 note=85 velocity=100 time=240
# note_off channel=0 note=85 velocity=0 time=240
# note_on channel=0 note=83 velocity=100 time=0
# note_off channel=0 note=83 velocity=0 time=240
# note_on channel=0 note=81 velocity=100 time=0
# note_off channel=0 note=81 velocity=0 time=240
# note_on channel=0 note=76 velocity=100 time=0
# note_off channel=0 note=76 velocity=0 time=720
# note_on channel=0 note=81 velocity=100 time=0
# note_off channel=0 note=81 velocity=0 time=240
# note_on channel=0 note=83 velocity=100 time=0
# note_off channel=0 note=83 velocity=0 time=480
# note_on channel=0 note=85 velocity=100 time=0
# note_off channel=0 note=85 velocity=0 time=480
# note_on channel=0 note=81 velocity=100 time=0
# note_off channel=0 note=81 velocity=0 time=480
# note_on channel=0 note=86 velocity=100 time=0
# note_off channel=0 note=86 velocity=0 time=720
# note_on channel=0 note=85 velocity=100 time=0
# note_off channel=0 note=85 velocity=0 time=720
# note_on channel=0 note=82 velocity=100 time=0
# note_off channel=0 note=82 velocity=0 time=480
# note_on channel=0 note=83 velocity=100 time=0
# note_off channel=0 note=83 velocity=0 time=720
# note_on channel=0 note=85 velocity=100 time=0
# note_off channel=0 note=85 velocity=0 time=240
# note_on channel=0 note=85 velocity=100 time=0
# note_off channel=0 note=85 velocity=0 time=240
# note_on channel=0 note=83 velocity=100 time=0
# note_off channel=0 note=83 velocity=0 time=240
# note_on channel=0 note=81 velocity=100 time=0
# note_off channel=0 note=81 velocity=0 time=240
# note_on channel=0 note=76 velocity=100 time=0
# note_off channel=0 note=76 velocity=0 time=720
# note_on channel=0 note=81 velocity=100 time=240
# note_off channel=0 note=81 velocity=0 time=240
# note_on channel=0 note=83 velocity=100 time=0
# note_off channel=0 note=83 velocity=0 time=480
# note_on channel=0 note=85 velocity=100 time=0
# note_off channel=0 note=85 velocity=0 time=480
# note_on channel=0 note=88 velocity=100 time=0
# note_off channel=0 note=88 velocity=0 time=480
# note_on channel=0 note=86 velocity=100 time=0
# note_off channel=0 note=86 velocity=0 time=720
# note_on channel=0 note=87 velocity=100 time=0
# note_off channel=0 note=87 velocity=0 time=720
# note_on channel=0 note=88 velocity=100 time=0
# note_off channel=0 note=88 velocity=0 time=480
# note_on channel=0 note=90 velocity=100 time=0
# note_off channel=0 note=90 velocity=0 time=240
# note_on channel=0 note=92 velocity=100 time=0
# note_off channel=0 note=92 velocity=0 time=720
# note_on channel=0 note=93 velocity=100 time=240
# note_off channel=0 note=93 velocity=0 time=480
# note_on channel=0 note=93 velocity=100 time=0
# note_off channel=0 note=93 velocity=0 time=240
# note_on channel=0 note=90 velocity=100 time=0
# note_off channel=0 note=90 velocity=0 time=240
# note_on channel=0 note=93 velocity=100 time=0
# note_off channel=0 note=93 velocity=0 time=240
# note_on channel=0 note=90 velocity=100 time=0
# note_off channel=0 note=90 velocity=0 time=240
# note_on channel=0 note=86 velocity=100 time=0
# note_off channel=0 note=86 velocity=0 time=480
# note_on channel=0 note=84 velocity=100 time=0
# note_off channel=0 note=84 velocity=0 time=240
# note_on channel=0 note=90 velocity=100 time=240
# note_off channel=0 note=90 velocity=0 time=240
# note_on channel=0 note=83 velocity=100 time=0
# note_off channel=0 note=83 velocity=0 time=240
# note_on channel=0 note=90 velocity=100 time=0
# note_off channel=0 note=90 velocity=0 time=240
# note_on channel=0 note=93 velocity=100 time=0
# note_off channel=0 note=93 velocity=0 time=480
# note_on channel=0 note=95 velocity=100 time=0
# note_off channel=0 note=95 velocity=0 time=480
# note_on channel=0 note=93 velocity=100 time=0
# note_off channel=0 note=93 velocity=0 time=720
# note_on channel=0 note=88 velocity=100 time=0
# note_off channel=0 note=88 velocity=0 time=720
# note_on channel=0 note=88 velocity=100 time=0
# note_off channel=0 note=88 velocity=0 time=240
# note_on channel=0 note=83 velocity=100 time=0
# note_off channel=0 note=83 velocity=0 time=240
# note_on channel=0 note=84 velocity=100 time=0
# note_off channel=0 note=84 velocity=0 time=480
# note_on channel=0 note=85 velocity=100 time=0
# note_off channel=0 note=85 velocity=0 time=480
# note_on channel=0 note=93 velocity=100 time=480
# note_off channel=0 note=93 velocity=0 time=480
# note_on channel=0 note=93 velocity=100 time=0
# note_off channel=0 note=93 velocity=0 time=240
# note_on channel=0 note=90 velocity=100 time=0
# note_off channel=0 note=90 velocity=0 time=240
# note_on channel=0 note=93 velocity=100 time=0
# note_off channel=0 note=93 velocity=0 time=240
# note_on channel=0 note=90 velocity=100 time=0
# note_off channel=0 note=90 velocity=0 time=240
# note_on channel=0 note=86 velocity=100 time=0
# note_off channel=0 note=86 velocity=0 time=240
# note_on channel=0 note=84 velocity=100 time=0
# note_off channel=0 note=84 velocity=0 time=480
# note_on channel=0 note=90 velocity=100 time=0
# note_off channel=0 note=90 velocity=0 time=240
# note_on channel=0 note=83 velocity=100 time=0
# note_off channel=0 note=83 velocity=0 time=240
# note_on channel=0 note=90 velocity=100 time=0
# note_off channel=0 note=90 velocity=0 time=240
# note_on channel=0 note=83 velocity=100 time=0
# note_off channel=0 note=83 velocity=0 time=480
# note_on channel=0 note=81 velocity=100 time=0
# note_off channel=0 note=81 velocity=0 time=480
# note_on channel=0 note=80 velocity=100 time=0
# note_off channel=0 note=80 velocity=0 time=480
# note_on channel=0 note=88 velocity=100 time=0
# note_off channel=0 note=88 velocity=0 time=480
# note_on channel=0 note=81 velocity=100 time=0
# note_off channel=0 note=81 velocity=0 time=480
# note_on channel=0 note=90 velocity=100 time=0
# note_off channel=0 note=90 velocity=0 time=240
# note_on channel=0 note=83 velocity=100 time=0
# note_off channel=0 note=83 velocity=0 time=480
# note_on channel=0 note=76 velocity=100 time=0
# note_off channel=0 note=76 velocity=0 time=720
# MetaMessage('end_of_track', time=0)

# %%
b'0'
# Out:
# b'0'

# %%
bytearray(0x00)
# Out:
# bytearray(b'')

# %%
0x91//16
# Out:
# 9
