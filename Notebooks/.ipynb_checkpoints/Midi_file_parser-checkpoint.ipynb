# %%
import struct

def read_variable_length(data, offset):
    # reads a variable acording to the midi the bottom 7 bits are used for value
    # if the 8th bit is 0 the value is done if the 8th bit is 1 grabs one more byte
    value = 0
    while True:
        byte = data[offset]
        offset += 1
        value = (value << 7) | (byte & 0x7F)
        if not (byte & 0x80):
            break
    return value, offset
    
def readMidiFile(path):
    src = open(path, "rb")
    current_time = 0
    while True:
        chunkID = src.read(4)
        chunklen = int.from_bytes(src.read(4))
        chunk = src.read(chunklen)
        header_dict = {}
        delta_times = False
        if chunkID == b'MThd':
            header_dict['format'], header_dict['ntracks'], header_dict['tickdiv']  = struct.unpack('>HHH', chunk[0:6])
            if header_dict['format'] != 1:
                    print('Only format 1 MIDI files are suported')
            print('Header: ', header_dict)
        elif chunkID == b'MTrk':
            offset = 0
            print("track:")
            #print(chunk)
            #b'\x00\xff\x03\x00\x00\xffX\x04\x04\x02\x18\x08\x00\xffQ\x03\x08,\xa2\x00\xff/\x00'

            while offset < chunklen:
                # Read delta time
                delta, offset = read_variable_length(chunk, offset)
                current_time += delta
                event_status = chunk[offset]
                offset += 1
                if event_status == 0xFF: #Meta event
                    meta_type = chunk[offset]
                    offset += 1
                    meta_length = chunk[offset]
                    offset += 1
                    meta_data = chunk[offset:offset+meta_length]
                    offset += meta_length
                    if meta_type == 0x2F and meta_data == b'':
                        print(current_time,"- Metadata > End of track")
                    elif meta_type == 0x03:
                        print(current_time,"- Metadata > Track/Sequence name > ",meta_data)
                    elif meta_type == 0x51:
                        tempo = struct.unpack('>i', b'\x00'+meta_data)[0]
                        print(current_time,"- Metadata > Tempo > ",tempo)
                    elif meta_type == 0x58:
                        num, denom, clocks_per_clck, notes_per_beat = struct.unpack('>bbbb', meta_data)
                        print(current_time,"- Metadata > Time signature >",num, denom, clocks_per_clck, notes_per_beat)
                    else:
                        print(current_time,'- type - ',meta_type,' - Meta Data > ',meta_data)
                elif event_status//16 == 9 or event_status//16 == 8:
                    note = chunk[offset]
                    offset += 1
                    vel = chunk[offset]
                    offset += 1
                    if event_status//16 == 9:
                        print(current_time,' - Note_On > n:',note,' v:',vel)
                    else:
                        print(current_time,' - Note_Off > n:',note,' v:',vel)
                elif event_status//16 == 11:
                    controller = chunk[offset]
                    offset += 1
                    value = chunk[offset]
                    offset += 1
                    print(current_time,' - controller > ctrl: ',controller,'val: ',value)
                elif event_status//16 == 12:
                    pgrm_n = chunk[offset]
                    offset += 1
                    print(current_time,' - program > pgrm_n: ',pgrm_n)
                elif event_status//16 == 14:
                    lsb = chunk[offset]
                    offset += 1
                    msb = chunk[offset]
                    offset += 1
                    print(current_time,' - pitchBend > lsb: ',lsb,' msb: ',msb)
                else:
                    print(current_time,' - ',hex(event_status))
        else:
            break

# %%
mid = readMidiFile('../ChipTune Melodies/Kid Dracula - Go-Go at the Great Castle.mid')
# Out:
# Header:  {'format': 1, 'ntracks': 2, 'tickdiv': 480}
# track:
# 0 - Metadata > Track/Sequence name >  b''
# 0 - Metadata > Time signature > 4 2 24 8
# 0 - Metadata > Tempo >  535714
# 0 - Metadata > End of track
# track:
# 0  - controller > ctrl:  121 val:  0
# 0 - Metadata > Track/Sequence name >  b'main track'
# 0  - controller > ctrl:  10 val:  64
# 0  - controller > ctrl:  7 val:  100
# 0  - controller > ctrl:  11 val:  127
# 0  - controller > ctrl:  101 val:  0
# 0  - controller > ctrl:  100 val:  2
# 0  - controller > ctrl:  6 val:  64
# 0  - controller > ctrl:  101 val:  0
# 0  - controller > ctrl:  100 val:  1
# 0  - controller > ctrl:  6 val:  64
# 0  - controller > ctrl:  38 val:  0
# 0  - controller > ctrl:  101 val:  0
# 0  - controller > ctrl:  100 val:  0
# 0  - controller > ctrl:  6 val:  12
# 0  - pitchBend > lsb:  0  msb:  64
# 0  - controller > ctrl:  1 val:  0
# 0  - program > pgrm_n:  80
# 720  - Note_On > n: 85  v: 100
# 960  - Note_Off > n: 85  v: 0
# 960  - Note_On > n: 83  v: 100
# 1200  - Note_Off > n: 83  v: 0
# 1200  - Note_On > n: 81  v: 100
# 1440  - Note_Off > n: 81  v: 0
# 1440  - Note_On > n: 76  v: 100
# 2160  - Note_Off > n: 76  v: 0
# 2400  - Note_On > n: 81  v: 100
# 2640  - Note_Off > n: 81  v: 0
# 2640  - Note_On > n: 83  v: 100
# 3120  - Note_Off > n: 83  v: 0
# 3120  - Note_On > n: 85  v: 100
# 3600  - Note_Off > n: 85  v: 0
# 3600  - Note_On > n: 81  v: 100
# 4080  - Note_Off > n: 81  v: 0
# 4080  - Note_On > n: 86  v: 100
# 4800  - Note_Off > n: 86  v: 0
# 4800  - Note_On > n: 85  v: 100
# 5520  - Note_Off > n: 85  v: 0
# 5520  - Note_On > n: 82  v: 100
# 6000  - Note_Off > n: 82  v: 0
# 6000  - Note_On > n: 83  v: 100
# 6720  - Note_Off > n: 83  v: 0
# 6960  - Note_On > n: 85  v: 100
# 7200  - Note_Off > n: 85  v: 0
# 7200  - Note_On > n: 83  v: 100
# 7440  - Note_Off > n: 83  v: 0
# 7440  - Note_On > n: 81  v: 100
# 7680  - Note_Off > n: 81  v: 0
# 7680  - Note_On > n: 76  v: 100
# 8400  - Note_Off > n: 76  v: 0
# 8400  - Note_On > n: 81  v: 100
# 8640  - Note_Off > n: 81  v: 0
# 8640  - Note_On > n: 83  v: 100
# 9120  - Note_Off > n: 83  v: 0
# 9120  - Note_On > n: 85  v: 100
# 9600  - Note_Off > n: 85  v: 0
# 9600  - Note_On > n: 88  v: 100
# 10080  - Note_Off > n: 88  v: 0
# 10080  - Note_On > n: 86  v: 100
# 11040  - Note_Off > n: 86  v: 0
# 11040  - Note_On > n: 88  v: 100
# 12000  - Note_Off > n: 88  v: 0
# 12000  - Note_On > n: 90  v: 100
# 12240  - Note_Off > n: 90  v: 0
# 12480  - Note_On > n: 90  v: 100
# 13200  - Note_Off > n: 90  v: 0
# 13440  - Note_On > n: 85  v: 100
# 13680  - Note_Off > n: 85  v: 0
# 13680  - Note_On > n: 83  v: 100
# 13920  - Note_Off > n: 83  v: 0
# 13920  - Note_On > n: 81  v: 100
# 14160  - Note_Off > n: 81  v: 0
# 14160  - Note_On > n: 76  v: 100
# 14880  - Note_Off > n: 76  v: 0
# 14880  - Note_On > n: 81  v: 100
# 15120  - Note_Off > n: 81  v: 0
# 15120  - Note_On > n: 83  v: 100
# 15600  - Note_Off > n: 83  v: 0
# 15600  - Note_On > n: 85  v: 100
# 16080  - Note_Off > n: 85  v: 0
# 16080  - Note_On > n: 81  v: 100
# 16560  - Note_Off > n: 81  v: 0
# 16560  - Note_On > n: 86  v: 100
# 17280  - Note_Off > n: 86  v: 0
# 17280  - Note_On > n: 85  v: 100
# 18000  - Note_Off > n: 85  v: 0
# 18000  - Note_On > n: 82  v: 100
# 18480  - Note_Off > n: 82  v: 0
# 18480  - Note_On > n: 83  v: 100
# 19200  - Note_Off > n: 83  v: 0
# 19200  - Note_On > n: 85  v: 100
# 19440  - Note_Off > n: 85  v: 0
# 19440  - Note_On > n: 85  v: 100
# 19680  - Note_Off > n: 85  v: 0
# 19680  - Note_On > n: 83  v: 100
# 19920  - Note_Off > n: 83  v: 0
# 19920  - Note_On > n: 81  v: 100
# 20160  - Note_Off > n: 81  v: 0
# 20160  - Note_On > n: 76  v: 100
# 20880  - Note_Off > n: 76  v: 0
# 21120  - Note_On > n: 81  v: 100
# 21360  - Note_Off > n: 81  v: 0
# 21360  - Note_On > n: 83  v: 100
# 21840  - Note_Off > n: 83  v: 0
# 21840  - Note_On > n: 85  v: 100
# 22320  - Note_Off > n: 85  v: 0
# 22320  - Note_On > n: 88  v: 100
# 22800  - Note_Off > n: 88  v: 0
# 22800  - Note_On > n: 86  v: 100
# 23520  - Note_Off > n: 86  v: 0
# 23520  - Note_On > n: 87  v: 100
# 24240  - Note_Off > n: 87  v: 0
# 24240  - Note_On > n: 88  v: 100
# 24720  - Note_Off > n: 88  v: 0
# 24720  - Note_On > n: 90  v: 100
# 24960  - Note_Off > n: 90  v: 0
# 24960  - Note_On > n: 92  v: 100
# 25680  - Note_Off > n: 92  v: 0
# 25920  - Note_On > n: 93  v: 100
# 26400  - Note_Off > n: 93  v: 0
# 26400  - Note_On > n: 93  v: 100
# 26640  - Note_Off > n: 93  v: 0
# 26640  - Note_On > n: 90  v: 100
# 26880  - Note_Off > n: 90  v: 0
# 26880  - Note_On > n: 93  v: 100
# 27120  - Note_Off > n: 93  v: 0
# 27120  - Note_On > n: 90  v: 100
# 27360  - Note_Off > n: 90  v: 0
# 27360  - Note_On > n: 86  v: 100
# 27840  - Note_Off > n: 86  v: 0
# 27840  - Note_On > n: 84  v: 100
# 28080  - Note_Off > n: 84  v: 0
# 28320  - Note_On > n: 90  v: 100
# 28560  - Note_Off > n: 90  v: 0
# 28560  - Note_On > n: 83  v: 100
# 28800  - Note_Off > n: 83  v: 0
# 28800  - Note_On > n: 90  v: 100
# 29040  - Note_Off > n: 90  v: 0
# 29040  - Note_On > n: 93  v: 100
# 29520  - Note_Off > n: 93  v: 0
# 29520  - Note_On > n: 95  v: 100
# 30000  - Note_Off > n: 95  v: 0
# 30000  - Note_On > n: 93  v: 100
# 30720  - Note_Off > n: 93  v: 0
# 30720  - Note_On > n: 88  v: 100
# 31440  - Note_Off > n: 88  v: 0
# 31440  - Note_On > n: 88  v: 100
# 31680  - Note_Off > n: 88  v: 0
# 31680  - Note_On > n: 83  v: 100
# 31920  - Note_Off > n: 83  v: 0
# 31920  - Note_On > n: 84  v: 100
# 32400  - Note_Off > n: 84  v: 0
# 32400  - Note_On > n: 85  v: 100
# 32880  - Note_Off > n: 85  v: 0
# 33360  - Note_On > n: 93  v: 100
# 33840  - Note_Off > n: 93  v: 0
# 33840  - Note_On > n: 93  v: 100
# 34080  - Note_Off > n: 93  v: 0
# 34080  - Note_On > n: 90  v: 100
# 34320  - Note_Off > n: 90  v: 0
# 34320  - Note_On > n: 93  v: 100
# 34560  - Note_Off > n: 93  v: 0
# 34560  - Note_On > n: 90  v: 100
# 34800  - Note_Off > n: 90  v: 0
# 34800  - Note_On > n: 86  v: 100
# 35040  - Note_Off > n: 86  v: 0
# 35040  - Note_On > n: 84  v: 100
# 35520  - Note_Off > n: 84  v: 0
# 35520  - Note_On > n: 90  v: 100
# 35760  - Note_Off > n: 90  v: 0
# 35760  - Note_On > n: 83  v: 100
# 36000  - Note_Off > n: 83  v: 0
# 36000  - Note_On > n: 90  v: 100
# 36240  - Note_Off > n: 90  v: 0
# 36240  - Note_On > n: 83  v: 100
# 36720  - Note_Off > n: 83  v: 0
# 36720  - Note_On > n: 81  v: 100
# 37200  - Note_Off > n: 81  v: 0
# 37200  - Note_On > n: 80  v: 100
# 37680  - Note_Off > n: 80  v: 0
# 37680  - Note_On > n: 88  v: 100
# 38160  - Note_Off > n: 88  v: 0
# 38160  - Note_On > n: 81  v: 100
# 38640  - Note_Off > n: 81  v: 0
# 38640  - Note_On > n: 90  v: 100
# 38880  - Note_Off > n: 90  v: 0
# 38880  - Note_On > n: 83  v: 100
# 39360  - Note_Off > n: 83  v: 0
# 39360  - Note_On > n: 76  v: 100
# 40080  - Note_Off > n: 76  v: 0
# 40080 - Metadata > End of track

# %%
from mido import MidiFile

# Load the MIDI file
mid = MidiFile('../ChipTune Melodies/Kid Dracula - Go-Go at the Great Castle.mid')

# Print file metadata
print(f"Type: {mid.type}, Ticks per beat: {mid.ticks_per_beat}")

# Iterate through tracks and messages
for track in mid.tracks:
    for msg in track:
        print(msg)
# Out:
# Type: 1, Ticks per beat: 480
# MetaMessage('track_name', name='', time=0)
# MetaMessage('time_signature', numerator=4, denominator=4, clocks_per_click=24, notated_32nd_notes_per_beat=8, time=0)
# MetaMessage('set_tempo', tempo=535714, time=0)
# MetaMessage('end_of_track', time=0)
# control_change channel=0 control=121 value=0 time=0
# MetaMessage('track_name', name='main track', time=0)
# control_change channel=0 control=10 value=64 time=0
# control_change channel=0 control=7 value=100 time=0
# control_change channel=0 control=11 value=127 time=0
# control_change channel=0 control=101 value=0 time=0
# control_change channel=0 control=100 value=2 time=0
# control_change channel=0 control=6 value=64 time=0
# control_change channel=0 control=101 value=0 time=0
# control_change channel=0 control=100 value=1 time=0
# control_change channel=0 control=6 value=64 time=0
# control_change channel=0 control=38 value=0 time=0
# control_change channel=0 control=101 value=0 time=0
# control_change channel=0 control=100 value=0 time=0
# control_change channel=0 control=6 value=12 time=0
# pitchwheel channel=0 pitch=0 time=0
# control_change channel=0 control=1 value=0 time=0
# program_change channel=0 program=80 time=0
# note_on channel=0 note=85 velocity=100 time=720
# note_off channel=0 note=85 velocity=0 time=240
# note_on channel=0 note=83 velocity=100 time=0
# note_off channel=0 note=83 velocity=0 time=240
# note_on channel=0 note=81 velocity=100 time=0
# note_off channel=0 note=81 velocity=0 time=240
# note_on channel=0 note=76 velocity=100 time=0
# note_off channel=0 note=76 velocity=0 time=720
# note_on channel=0 note=81 velocity=100 time=240
# note_off channel=0 note=81 velocity=0 time=240
# note_on channel=0 note=83 velocity=100 time=0
# note_off channel=0 note=83 velocity=0 time=480
# note_on channel=0 note=85 velocity=100 time=0
# note_off channel=0 note=85 velocity=0 time=480
# note_on channel=0 note=81 velocity=100 time=0
# note_off channel=0 note=81 velocity=0 time=480
# note_on channel=0 note=86 velocity=100 time=0
# note_off channel=0 note=86 velocity=0 time=720
# note_on channel=0 note=85 velocity=100 time=0
# note_off channel=0 note=85 velocity=0 time=720
# note_on channel=0 note=82 velocity=100 time=0
# note_off channel=0 note=82 velocity=0 time=480
# note_on channel=0 note=83 velocity=100 time=0
# note_off channel=0 note=83 velocity=0 time=720
# note_on channel=0 note=85 velocity=100 time=240
# note_off channel=0 note=85 velocity=0 time=240
# note_on channel=0 note=83 velocity=100 time=0
# note_off channel=0 note=83 velocity=0 time=240
# note_on channel=0 note=81 velocity=100 time=0
# note_off channel=0 note=81 velocity=0 time=240
# note_on channel=0 note=76 velocity=100 time=0
# note_off channel=0 note=76 velocity=0 time=720
# note_on channel=0 note=81 velocity=100 time=0
# note_off channel=0 note=81 velocity=0 time=240
# note_on channel=0 note=83 velocity=100 time=0
# note_off channel=0 note=83 velocity=0 time=480
# note_on channel=0 note=85 velocity=100 time=0
# note_off channel=0 note=85 velocity=0 time=480
# note_on channel=0 note=88 velocity=100 time=0
# note_off channel=0 note=88 velocity=0 time=480
# note_on channel=0 note=86 velocity=100 time=0
# note_off channel=0 note=86 velocity=0 time=960
# note_on channel=0 note=88 velocity=100 time=0
# note_off channel=0 note=88 velocity=0 time=960
# note_on channel=0 note=90 velocity=100 time=0
# note_off channel=0 note=90 velocity=0 time=240
# note_on channel=0 note=90 velocity=100 time=240
# note_off channel=0 note=90 velocity=0 time=720
# note_on channel=0 note=85 velocity=100 time=240
# note_off channel=0 note=85 velocity=0 time=240
# note_on channel=0 note=83 velocity=100 time=0
# note_off channel=0 note=83 velocity=0 time=240
# note_on channel=0 note=81 velocity=100 time=0
# note_off channel=0 note=81 velocity=0 time=240
# note_on channel=0 note=76 velocity=100 time=0
# note_off channel=0 note=76 velocity=0 time=720
# note_on channel=0 note=81 velocity=100 time=0
# note_off channel=0 note=81 velocity=0 time=240
# note_on channel=0 note=83 velocity=100 time=0
# note_off channel=0 note=83 velocity=0 time=480
# note_on channel=0 note=85 velocity=100 time=0
# note_off channel=0 note=85 velocity=0 time=480
# note_on channel=0 note=81 velocity=100 time=0
# note_off channel=0 note=81 velocity=0 time=480
# note_on channel=0 note=86 velocity=100 time=0
# note_off channel=0 note=86 velocity=0 time=720
# note_on channel=0 note=85 velocity=100 time=0
# note_off channel=0 note=85 velocity=0 time=720
# note_on channel=0 note=82 velocity=100 time=0
# note_off channel=0 note=82 velocity=0 time=480
# note_on channel=0 note=83 velocity=100 time=0
# note_off channel=0 note=83 velocity=0 time=720
# note_on channel=0 note=85 velocity=100 time=0
# note_off channel=0 note=85 velocity=0 time=240
# note_on channel=0 note=85 velocity=100 time=0
# note_off channel=0 note=85 velocity=0 time=240
# note_on channel=0 note=83 velocity=100 time=0
# note_off channel=0 note=83 velocity=0 time=240
# note_on channel=0 note=81 velocity=100 time=0
# note_off channel=0 note=81 velocity=0 time=240
# note_on channel=0 note=76 velocity=100 time=0
# note_off channel=0 note=76 velocity=0 time=720
# note_on channel=0 note=81 velocity=100 time=240
# note_off channel=0 note=81 velocity=0 time=240
# note_on channel=0 note=83 velocity=100 time=0
# note_off channel=0 note=83 velocity=0 time=480
# note_on channel=0 note=85 velocity=100 time=0
# note_off channel=0 note=85 velocity=0 time=480
# note_on channel=0 note=88 velocity=100 time=0
# note_off channel=0 note=88 velocity=0 time=480
# note_on channel=0 note=86 velocity=100 time=0
# note_off channel=0 note=86 velocity=0 time=720
# note_on channel=0 note=87 velocity=100 time=0
# note_off channel=0 note=87 velocity=0 time=720
# note_on channel=0 note=88 velocity=100 time=0
# note_off channel=0 note=88 velocity=0 time=480
# note_on channel=0 note=90 velocity=100 time=0
# note_off channel=0 note=90 velocity=0 time=240
# note_on channel=0 note=92 velocity=100 time=0
# note_off channel=0 note=92 velocity=0 time=720
# note_on channel=0 note=93 velocity=100 time=240
# note_off channel=0 note=93 velocity=0 time=480
# note_on channel=0 note=93 velocity=100 time=0
# note_off channel=0 note=93 velocity=0 time=240
# note_on channel=0 note=90 velocity=100 time=0
# note_off channel=0 note=90 velocity=0 time=240
# note_on channel=0 note=93 velocity=100 time=0
# note_off channel=0 note=93 velocity=0 time=240
# note_on channel=0 note=90 velocity=100 time=0
# note_off channel=0 note=90 velocity=0 time=240
# note_on channel=0 note=86 velocity=100 time=0
# note_off channel=0 note=86 velocity=0 time=480
# note_on channel=0 note=84 velocity=100 time=0
# note_off channel=0 note=84 velocity=0 time=240
# note_on channel=0 note=90 velocity=100 time=240
# note_off channel=0 note=90 velocity=0 time=240
# note_on channel=0 note=83 velocity=100 time=0
# note_off channel=0 note=83 velocity=0 time=240
# note_on channel=0 note=90 velocity=100 time=0
# note_off channel=0 note=90 velocity=0 time=240
# note_on channel=0 note=93 velocity=100 time=0
# note_off channel=0 note=93 velocity=0 time=480
# note_on channel=0 note=95 velocity=100 time=0
# note_off channel=0 note=95 velocity=0 time=480
# note_on channel=0 note=93 velocity=100 time=0
# note_off channel=0 note=93 velocity=0 time=720
# note_on channel=0 note=88 velocity=100 time=0
# note_off channel=0 note=88 velocity=0 time=720
# note_on channel=0 note=88 velocity=100 time=0
# note_off channel=0 note=88 velocity=0 time=240
# note_on channel=0 note=83 velocity=100 time=0
# note_off channel=0 note=83 velocity=0 time=240
# note_on channel=0 note=84 velocity=100 time=0
# note_off channel=0 note=84 velocity=0 time=480
# note_on channel=0 note=85 velocity=100 time=0
# note_off channel=0 note=85 velocity=0 time=480
# note_on channel=0 note=93 velocity=100 time=480
# note_off channel=0 note=93 velocity=0 time=480
# note_on channel=0 note=93 velocity=100 time=0
# note_off channel=0 note=93 velocity=0 time=240
# note_on channel=0 note=90 velocity=100 time=0
# note_off channel=0 note=90 velocity=0 time=240
# note_on channel=0 note=93 velocity=100 time=0
# note_off channel=0 note=93 velocity=0 time=240
# note_on channel=0 note=90 velocity=100 time=0
# note_off channel=0 note=90 velocity=0 time=240
# note_on channel=0 note=86 velocity=100 time=0
# note_off channel=0 note=86 velocity=0 time=240
# note_on channel=0 note=84 velocity=100 time=0
# note_off channel=0 note=84 velocity=0 time=480
# note_on channel=0 note=90 velocity=100 time=0
# note_off channel=0 note=90 velocity=0 time=240
# note_on channel=0 note=83 velocity=100 time=0
# note_off channel=0 note=83 velocity=0 time=240
# note_on channel=0 note=90 velocity=100 time=0
# note_off channel=0 note=90 velocity=0 time=240
# note_on channel=0 note=83 velocity=100 time=0
# note_off channel=0 note=83 velocity=0 time=480
# note_on channel=0 note=81 velocity=100 time=0
# note_off channel=0 note=81 velocity=0 time=480
# note_on channel=0 note=80 velocity=100 time=0
# note_off channel=0 note=80 velocity=0 time=480
# note_on channel=0 note=88 velocity=100 time=0
# note_off channel=0 note=88 velocity=0 time=480
# note_on channel=0 note=81 velocity=100 time=0
# note_off channel=0 note=81 velocity=0 time=480
# note_on channel=0 note=90 velocity=100 time=0
# note_off channel=0 note=90 velocity=0 time=240
# note_on channel=0 note=83 velocity=100 time=0
# note_off channel=0 note=83 velocity=0 time=480
# note_on channel=0 note=76 velocity=100 time=0
# note_off channel=0 note=76 velocity=0 time=720
# MetaMessage('end_of_track', time=0)

# %%
b'0'
# Out:
# b'0'

# %%
bytearray(0x00)
# Out:
# bytearray(b'')

# %%
0x91//16
# Out:
# 9
